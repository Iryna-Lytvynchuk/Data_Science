# %% [markdown]
# <a href="https://colab.research.google.com/github/Iryna-Lytvynchuk/Data_Science/blob/main/stock_profitability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

data = pd.DataFrame(
    {
        "Момент наблюдения": [
            1,
            2,
            3,
            4,
            5,
            6,
        ],
        "Доходность A, %": [
            25,
            -10,
            10,
            5,
            35,
            13,
        ],
        "Доходность B, %": [
            0,
            15,
            -5,
            5,
            20,
            25,
        ],
        "Доходность C, %": [
            10,
            25,
            -15,
            -5,
            -5,
            15,
        ],
    },
)

print(data)

sns.regplot(x="Доходность A, %", y="Доходность B, %", data=data, order=1, ci=None)
# Out:
#    Момент наблюдения  Доходность A, %  Доходность B, %  Доходность C, %
# 0                  1               25                0               10
# 1                  2              -10               15               25
# 2                  3               10               -5              -15
# 3                  4                5                5               -5
# 4                  5               35               20               -5
# 5                  6               13               25               15

# %%
sns.regplot(x="Доходность A, %", y="Доходность C, %", data=data, order=2, ci=None)

# %%
sns.regplot(x="Доходность B, %", y="Доходность C, %", data=data, order=2, ci=None)
